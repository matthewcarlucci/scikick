# %%
from scikick import skdir
import os
os.chdir(skdir())

# %%
file = open("output/first_data.txt", "w")
for i in range(100):
    file.write(str(i))
file.close()

# %%
print("AAA")
# Out:
# AAA

# %%
import matplotlib.pyplot as pyplot

pyplot.title('Example')
pyplot.plot([1, 2, 3, 4, 5], [1, 5, 2, 4, 3])
pyplot.show()
